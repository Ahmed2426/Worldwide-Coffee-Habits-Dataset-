# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
coffee = pd.read_csv("worldwide_coffee_habits.csv")
coffee
# Out:
#          Country  Year  Coffee Consumption (kg per capita per year)  \
# 0     Country_39  2023                                     9.253939
# 1     Country_29  2011                                     9.981203
# 2     Country_15  2020                                     3.312916
# 3     Country_43  2005                                     2.436180
# 4      Country_8  2019                                     4.637849
# ...          ...   ...                                          ...
# 9995  Country_26  2013                                     6.107139
# 9996  Country_22  2013                                     7.848531
# 9997  Country_31  2019                                     2.152059
# 9998  Country_43  2012                                     5.715941
# 9999  Country_10  2002                                     9.210541
#
#       Average Coffee Price (USD per kg) Type of Coffee Consumed  \
# 0                              6.467453               Americano
# 1                              4.346744                   Mocha
# 2                              8.767496                   Latte
# 3                             11.748750                Espresso
# 4                              8.999099                   Mocha
# ...                                 ...                     ...
# 9995                          11.553694                   Mocha
# 9996                          14.844245               Americano
# 9997                           5.516845               Americano
# 9998                           4.641472              Cappuccino
# 9999                           7.022841               Americano
#
#       Population (millions)
# 0                 65.929478
# 1                 82.456680
# 2                110.938862
# 3                 43.137207
# 4                 65.484262
# ...                     ...
# 9995              95.808370
# 9996             121.098306
# 9997              97.327529
# 9998              33.916437
# 9999              43.327649
#
# [10000 rows x 6 columns]

# %%
coffee.sample(11)
# Out:
#          Country  Year  Coffee Consumption (kg per capita per year)  \
# 1962  Country_12  2015                                     3.120314
# 5279  Country_43  2012                                     9.569570
# 3185  Country_46  2020                                     7.079961
# 9482  Country_45  2003                                     4.683695
# 4500  Country_37  2007                                     8.259515
# 5698  Country_40  2001                                     7.891118
# 3544  Country_27  2013                                     4.787963
# 8088  Country_34  2012                                     2.510731
# 2233   Country_8  2005                                     3.349026
# 7046  Country_18  2020                                     8.437566
# 5274  Country_38  2022                                     4.671628
#
#       Average Coffee Price (USD per kg) Type of Coffee Consumed  \
# 1962                          14.327801               Americano
# 5279                           7.657812                Espresso
# 3185                           5.973935                Espresso
# 9482                           6.243932                Espresso
# 4500                          12.063519               Americano
# 5698                          11.135320                   Latte
# 3544                           7.948977                   Mocha
# 8088                           4.226840              Cappuccino
# 2233                           4.886830                Espresso
# 7046                          13.525409                   Mocha
# 5274                           4.680682              Cappuccino
#
#       Population (millions)
# 1962              85.194360
# 5279              85.483302
# 3185              27.979982
# 9482              55.195955
# 4500             101.892933
# 5698             118.266271
# 3544              55.917610
# 8088              37.080875
# 2233             111.204985
# 7046               2.287569
# 5274             141.544623

# %%
coffee.head(11)
# Out:
#          Country  Year  Coffee Consumption (kg per capita per year)  \
# 9989   Country_5  2002                                     5.013729
# 9990  Country_18  2017                                     6.616937
# 9991  Country_16  2021                                     2.690185
# 9992   Country_8  2005                                     4.870431
# 9993  Country_25  2016                                     5.296394
# 9994  Country_32  2022                                     8.681899
# 9995  Country_26  2013                                     6.107139
# 9996  Country_22  2013                                     7.848531
# 9997  Country_31  2019                                     2.152059
# 9998  Country_43  2012                                     5.715941
# 9999  Country_10  2002                                     9.210541
#
#       Average Coffee Price (USD per kg) Type of Coffee Consumed  \
# 9989                           5.296476                   Latte
# 9990                           4.569999               Americano
# 9991                           9.854513               Americano
# 9992                          10.850213              Cappuccino
# 9993                           8.438758                Espresso
# 9994                          12.776924                   Latte
# 9995                          11.553694                   Mocha
# 9996                          14.844245               Americano
# 9997                           5.516845               Americano
# 9998                           4.641472              Cappuccino
# 9999                           7.022841               Americano
#
#       Population (millions)
# 9989              12.151836
# 9990             102.133135
# 9991             134.742075
# 9992              76.142792
# 9993              74.560103
# 9994             148.720623
# 9995              95.808370
# 9996             121.098306
# 9997              97.327529
# 9998              33.916437
# 9999              43.327649

# %%
coffee.tail(11)
# Out:
#          Country  Year  Coffee Consumption (kg per capita per year)  \
# 9989   Country_5  2002                                     5.013729
# 9990  Country_18  2017                                     6.616937
# 9991  Country_16  2021                                     2.690185
# 9992   Country_8  2005                                     4.870431
# 9993  Country_25  2016                                     5.296394
# 9994  Country_32  2022                                     8.681899
# 9995  Country_26  2013                                     6.107139
# 9996  Country_22  2013                                     7.848531
# 9997  Country_31  2019                                     2.152059
# 9998  Country_43  2012                                     5.715941
# 9999  Country_10  2002                                     9.210541
#
#       Average Coffee Price (USD per kg) Type of Coffee Consumed  \
# 9989                           5.296476                   Latte
# 9990                           4.569999               Americano
# 9991                           9.854513               Americano
# 9992                          10.850213              Cappuccino
# 9993                           8.438758                Espresso
# 9994                          12.776924                   Latte
# 9995                          11.553694                   Mocha
# 9996                          14.844245               Americano
# 9997                           5.516845               Americano
# 9998                           4.641472              Cappuccino
# 9999                           7.022841               Americano
#
#       Population (millions)
# 9989              12.151836
# 9990             102.133135
# 9991             134.742075
# 9992              76.142792
# 9993              74.560103
# 9994             148.720623
# 9995              95.808370
# 9996             121.098306
# 9997              97.327529
# 9998              33.916437
# 9999              43.327649

# %%
coffee.isnull().sum()
# Out:
# Country                                        0
# Year                                           0
# Coffee Consumption (kg per capita per year)    0
# Average Coffee Price (USD per kg)              0
# Type of Coffee Consumed                        0
# Population (millions)                          0
# dtype: int64

# %%
coffee.dropna
# Out:
# <bound method DataFrame.dropna of          Country  Year  Coffee Consumption (kg per capita per year)  \
# 0     Country_39  2023                                     9.253939
# 1     Country_29  2011                                     9.981203
# 2     Country_15  2020                                     3.312916
# 3     Country_43  2005                                     2.436180
# 4      Country_8  2019                                     4.637849
# ...          ...   ...                                          ...
# 9995  Country_26  2013                                     6.107139
# 9996  Country_22  2013                                     7.848531
# 9997  Country_31  2019                                     2.152059
# 9998  Country_43  2012                                     5.715941
# 9999  Country_10  2002                                     9.210541
#
#       Average Coffee Price (USD per kg) Type of Coffee Consumed  \
# 0                              6.467453               Americano
# 1                              4.346744                   Mocha
# 2                              8.767496                   Latte
# 3                             11.748750                Espresso
# 4                              8.999099                   Mocha
# ...                                 ...                     ...
# 9995                          11.553694                   Mocha
# 9996                          14.844245               Americano
# 9997                           5.516845               Americano
# 9998                           4.641472              Cappuccino
# 9999                           7.022841               Americano
#
#       Population (millions)
# 0                 65.929478
# 1                 82.456680
# 2                110.938862
# 3                 43.137207
# 4                 65.484262
# ...                     ...
# 9995              95.808370
# 9996             121.098306
# 9997              97.327529
# 9998              33.916437
# 9999              43.327649
#
# [10000 rows x 6 columns]>

# %%
coffee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Country                                      10000 non-null  object
#  1   Year                                         10000 non-null  int64
#  2   Coffee Consumption (kg per capita per year)  10000 non-null  float64
#  3   Average Coffee Price (USD per kg)            10000 non-null  float64
#  4   Type of Coffee Consumed                      10000 non-null  object
#  5   Population (millions)                        10000 non-null  float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 468.9+ KB

# %%
coffee.describe()
# Out:
#                Year  Coffee Consumption (kg per capita per year)  \
# count  10000.000000                                 10000.000000
# mean    2011.666900                                     6.061865
# std        6.911695                                     2.313427
# min     2000.000000                                     2.000385
# 25%     2006.000000                                     4.070743
# 50%     2012.000000                                     6.094491
# 75%     2018.000000                                     8.061127
# max     2023.000000                                     9.999399
#
#        Average Coffee Price (USD per kg)  Population (millions)
# count                       10000.000000           10000.000000
# mean                            9.461891              75.167120
# std                             3.151403              43.023176
# min                             4.000742               1.002494
# 25%                             6.728261              37.465847
# 50%                             9.458371              75.021943
# 75%                            12.136285             112.595868
# max                            14.997053             149.995850

# %%
coffee['Type of Coffee Consumed'].value_counts()
# Out:
# Type of Coffee Consumed
# Latte         2071
# Cappuccino    2001
# Mocha         1984
# Americano     1975
# Espresso      1969
# Name: count, dtype: int64

# %%
coffee['Country'].value_counts()
# Out:
# Country
# Country_26    232
# Country_49    225
# Country_45    225
# Country_23    223
# Country_28    221
# Country_17    220
# Country_47    219
# Country_35    218
# Country_29    213
# Country_32    213
# Country_18    213
# Country_21    211
# Country_25    211
# Country_39    209
# Country_13    208
# Country_12    207
# Country_42    206
# Country_2     205
# Country_37    205
# Country_8     205
# Country_15    205
# Country_22    205
# Country_40    204
# Country_44    203
# Country_34    202
# Country_4     201
# Country_20    198
# Country_24    198
# Country_3     197
# Country_5     195
# Country_11    195
# Country_33    194
# Country_6     194
# Country_38    194
# Country_16    193
# Country_36    193
# Country_19    193
# Country_48    191
# Country_30    191
# Country_9     189
# Country_14    188
# Country_50    184
# Country_10    183
# Country_1     181
# Country_46    180
# Country_41    178
# Country_43    176
# Country_7     172
# Country_27    169
# Country_31    165
# Name: count, dtype: int64

# %%
def simple_lineplot(title, data, x, y):
    plt.figure(figsize=(10,6))
    plt.title(title)
    sns.lineplot(data=data, x=x, y=y, marker='o')
    plt.xticks(data[x].unique(), rotation=45)
    plt.grid(True)
    plt.show()

# %%
year_mean = lambda data, col, name: data.groupby('Year')[col].mean().reset_index(name=name)

consumption_years = year_mean(coffee, 'Coffee Consumption (kg per capita per year)', 'Consumption')
simple_lineplot('Average Coffee Consumption through the Years', consumption_years, 'Year', 'Consumption')

# %%
price_years = year_mean(coffee, 'Average Coffee Price (USD per kg)', 'Price')
simple_lineplot('Average Coffee Price through the Years', price_years, 'Year', 'Price')

# %%
for coffee_type in coffee['Type of Coffee Consumed'].unique():
    data = coffee[coffee['Type of Coffee Consumed'] == coffee_type]
    
    data_consumption = year_mean(data, 'Coffee Consumption (kg per capita per year)', 'Consumption')
    data_price = year_mean(data, 'Average Coffee Price (USD per kg)', 'Price')
    
    simple_lineplot(f'{coffee_type} Average Coffee Consumption through the Years', data_consumption, 'Year', 'Consumption')
    simple_lineplot(f'{coffee_type} Average Coffee Price through the Years', data_price, 'Year', 'Price')
